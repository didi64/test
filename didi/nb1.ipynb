# %%
! pwd
# Out:
# /home/jovyan

# %%
! rm -rf test

# %%
! ls test
# Out:
# ls: cannot access 'test': No such file or directory

# %%
# %%bash
# git clone https://github.com/didi64/test.git
#
# mkdir mkdir/didi
# cp nb1.ipynb test/didi/.
# git add didi/nb1.ipynb
# git commit -m 'nb1 added'
